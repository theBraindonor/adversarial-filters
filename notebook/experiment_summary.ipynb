# %% [markdown]
# # Experiment Summary
# This notebook will print out a summary of the filter experiments for the four networks.

# %%
# Base library imports
import os
import re

# Module imports
from IPython.display import display, HTML
import pandas as pd

# Quick pathfix required before loading project resources
try:
    notebook_location
except NameError:
    notebook_location = os.getcwd()
    os.chdir(re.sub(r'(adversarial-filters)[\\/].*', r'\1', notebook_location))

# %%
sample = 100
filters = [
    'color_blindness_filter',
    'daltonization_filter',
    'daltonization_lab_enhance_filter',
    'fourier_ellipsoid_filter',
    'fourier_gaussian_filter',
    'fourier_uniform_filter',
    'gaussian_filter',
    'gaussian_noise_filter',
    'histogram_equalization_filter',
    'salt_pepper_noise_filter',
    'speckle_noise_filter',
    'wavelet_denoise_filter'
]
filter_names = [
    'Color Blindness',
    'Daltonization',
    'Daltonization + LAB Enhance',
    'Fourier Ellipsoid',
    'Fourier Gaussian',
    'Fourier Uniform',
    'Gaussian',
    'Gaussian Noise',
    'Histogram Equalization',
    'Salt & Pepper Noise',
    'Speckle Noise',
    'Wavelet Denoise'
]
networks = ['vgg16', 'vgg19', 'densenet201', 'resnet152v2']
column_array = [
    ['VGG16', 'VGG16', 'VGG19', 'VGG19', 'DenseNet201', 'DenseNet201', 'ResNet152v2', 'ResNet152v2'],
    ['Accuracy', 'EOT', 'Accuracy', 'EOT', 'Accuracy', 'EOT', 'Accuracy', 'EOT']
]
column_names = [
    'Network', 'Score'
]
filename = 'log/%s_%s_%s_search.csv'

# %%
scores = dict()
for network in networks:
    scores['%s_acc' % network] = list()
    scores['%s_eot' % network] = list()
for filter in filters:
    for network in networks:
        score_df = pd.read_csv(filename % (filter, network, sample))
        score_df.sort_values('adjusted_eot', ascending=False, inplace=True)
        scores['%s_acc' % network].append(score_df.iloc[0].at['accuracy'])
        scores['%s_eot' % network].append(score_df.iloc[0].at['adjusted_eot'])
        
scores_df = pd.DataFrame(scores, index=filter_names)
scores_df.columns=pd.MultiIndex.from_arrays(column_array, names=column_names)
display(scores_df)
# Out:
# Network                        VGG16              VGG19           DenseNet201  \
# Score                       Accuracy       EOT Accuracy       EOT    Accuracy
# Color Blindness                 0.79 -3.361490     0.79 -3.176949        0.84
# Daltonization                   0.90 -3.241074     0.98 -3.389703        0.98
# Daltonization + LAB Enhance     0.83 -3.599140     0.92 -3.733325        0.96
# Fourier Ellipsoid               0.66 -2.521318     0.68 -2.492385        0.47
# Fourier Gaussian                0.57 -2.457981     0.32 -2.463767        0.26
# Fourier Uniform                 0.58 -2.548874     0.61 -2.553059        0.52
# Gaussian                        0.48 -2.358349     0.34 -2.388842        0.29
# Gaussian Noise                  0.67 -4.993688     0.83 -4.885813        0.75
# Histogram Equalization          0.90 -5.008721     0.87 -5.301215        0.91
# Salt & Pepper Noise             0.73 -1.204454     0.60 -0.974985        0.73
# Speckle Noise                   0.65 -4.538521     0.62 -4.380236        0.64
# Wavelet Denoise                 0.32 -1.927197     0.35 -1.989937        0.33
#
# Network                               ResNet152v2
# Score                             EOT    Accuracy       EOT
# Color Blindness             -3.549087        0.93 -4.466952
# Daltonization               -3.779053        0.95 -4.102333
# Daltonization + LAB Enhance -4.244866        0.97 -4.598454
# Fourier Ellipsoid           -2.611163        0.28 -2.255368
# Fourier Gaussian            -2.370208        0.27 -2.231547
# Fourier Uniform             -2.573108        0.26 -2.268564
# Gaussian                    -2.260296        0.21 -2.157805
# Gaussian Noise              -5.286561        0.75 -5.479339
# Histogram Equalization      -5.814093        0.93 -5.983390
# Salt & Pepper Noise         -1.323589        0.70 -1.521014
# Speckle Noise               -4.670359        0.67 -4.913843
# Wavelet Denoise             -2.156374        0.35 -2.025208

# %%
column_array = [
    ['VGG16', 'VGG16', 'VGG19', 'VGG19', 'DenseNet201', 'DenseNet201', 'ResNet152v2', 'ResNet152v2'],
    ['Accuracy', 'EOT', 'Accuracy', 'EOT', 'Accuracy', 'EOT', 'Accuracy', 'EOT']
]
sample = 1000
scores = dict()
for network in networks:
    scores['%s_acc' % network] = list()
    scores['%s_eot' % network] = list()
for filter in filters:
    for network in networks:
        score_df = pd.read_csv(filename % (filter, network, sample))
        score_df.sort_values('adjusted_eot', ascending=False, inplace=True)
        scores['%s_acc' % network].append(score_df.iloc[0].at['accuracy'])
        scores['%s_eot' % network].append(score_df.iloc[0].at['adjusted_eot'])
        
scores_df = pd.DataFrame(scores, index=filter_names)
scores_df.columns=pd.MultiIndex.from_arrays(column_array, names=column_names)
display(scores_df)
# Out:
# Network                        VGG16              VGG19           DenseNet201  \
# Score                       Accuracy       EOT Accuracy       EOT    Accuracy
# Color Blindness                0.778 -2.991821    0.790 -3.026268       0.837
# Daltonization                  0.898 -3.082998    0.920 -3.101274       0.966
# Daltonization + LAB Enhance    0.893 -3.503092    0.905 -3.506932       0.934
# Fourier Ellipsoid              0.529 -2.436966    0.562 -2.363331       0.426
# Fourier Gaussian               0.493 -2.383923    0.445 -2.341322       0.317
# Fourier Uniform                0.536 -2.454700    0.561 -2.381613       0.401
# Gaussian                       0.456 -2.330773    0.480 -2.321251       0.313
# Gaussian Noise                 0.703 -4.897100    0.688 -4.894430       0.784
# Histogram Equalization         0.871 -4.891757    0.876 -4.904003       0.908
# Salt & Pepper Noise            0.693 -1.114599    0.676 -1.121258       0.774
# Speckle Noise                  0.661 -4.494809    0.643 -4.477865       0.705
# Wavelet Denoise                0.348 -1.985292    0.373 -2.015749       0.336
#
# Network                               ResNet152v2
# Score                             EOT    Accuracy       EOT
# Color Blindness             -3.408125       0.921 -4.337812
# Daltonization               -3.594180       0.986 -4.273004
# Daltonization + LAB Enhance -3.965566       0.964 -4.701019
# Fourier Ellipsoid           -2.611468       0.390 -2.430101
# Fourier Gaussian            -2.469083       0.309 -2.323531
# Fourier Uniform             -2.601603       0.320 -2.390671
# Gaussian                    -2.379892       0.316 -2.253083
# Gaussian Noise              -5.263329       0.807 -5.721560
# Histogram Equalization      -5.348802       0.918 -5.844388
# Salt & Pepper Noise         -1.288477       0.756 -1.712846
# Speckle Noise               -4.717955       0.723 -5.170360
# Wavelet Denoise             -2.063485       0.351 -2.132400

# %%
column_array = [
    ['VGG16', 'VGG16', 'VGG19', 'VGG19', 'DenseNet201', 'DenseNet201', 'ResNet152v2', 'ResNet152v2'],
    ['EOT', 'Max Index', 'EOT', 'Max Index', 'EOT', 'Max Index', 'EOT', 'Max Index']
]
scores = dict()
for network in networks:
    scores['%s_eot' % network] = list()
    scores['%s_max' % network] = list()
for filter in filters:
    for network in networks:
        score_df = pd.read_csv(filename % (filter, network, sample))
        score_df.sort_values('raw_eot', ascending=False, inplace=True)
        scores['%s_eot' % network].append(score_df.iloc[0].at['raw_eot'])
        scores['%s_max' % network].append(score_df.iloc[0].at['max_score_index'])
        
scores_df = pd.DataFrame(scores, index=filter_names)
scores_df.columns=pd.MultiIndex.from_arrays(column_array, names=column_names)
display(scores_df)
# Out:
# Network                         VGG16               VGG19            \
# Score                             EOT Max Index       EOT Max Index
# Color Blindness             -0.833106     744.0 -0.799884     162.0
# Daltonization               -0.770482     744.0 -0.747041     162.0
# Daltonization + LAB Enhance -1.079270     744.0 -1.048559     162.0
# Fourier Ellipsoid           -1.048473     873.0 -1.037638     867.0
# Fourier Gaussian            -1.052748     744.0 -1.129505     609.0
# Fourier Uniform             -1.104744     873.0 -1.035964     609.0
# Gaussian                    -1.129019     412.0 -1.025240     609.0
# Gaussian Noise              -2.008139     873.0 -1.629885     359.0
# Histogram Equalization      -1.570002     699.0 -1.520427     162.0
# Salt & Pepper Noise         -0.214272     692.0 -0.154184     359.0
# Speckle Noise               -1.465744     503.0 -1.167335     500.0
# Wavelet Denoise             -0.844795     873.0 -0.908315     609.0
#
# Network                     DenseNet201           ResNet152v2
# Score                               EOT Max Index         EOT Max Index
# Color Blindness               -0.742272     392.0   -1.074284     783.0
# Daltonization                 -1.251888     716.0   -0.913248     783.0
# Daltonization + LAB Enhance   -1.231898     716.0   -1.231178     661.0
# Fourier Ellipsoid             -0.848329     976.0   -1.106515     282.0
# Fourier Gaussian              -1.030133     976.0   -0.945734     914.0
# Fourier Uniform               -0.837184     976.0   -1.053033     661.0
# Gaussian                      -0.973249     976.0   -0.920335     914.0
# Gaussian Noise                -1.909879     690.0   -1.783610     641.0
# Histogram Equalization        -1.920190     969.0   -1.702434     721.0
# Salt & Pepper Noise           -0.161626     182.0   -0.149064     604.0
# Speckle Noise                 -1.133347     560.0   -1.076575     528.0
# Wavelet Denoise               -0.940616     690.0   -0.743577     914.0
