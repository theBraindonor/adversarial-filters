# %% [markdown]
# # Filter Demonstrations
# This notebook runs each of the filters against a known image using the values uncovered during the experiments.

# %%
# Base library imports
import os
import re

# Module imports
import numpy as np
from skimage import img_as_int
from skimage.filters import gaussian
from skimage.io import imshow

# Quick pathfix required before loading project resources
try:
    notebook_location
except NameError:
    notebook_location = os.getcwd()
    os.chdir(re.sub(r'(adversarial-filters)[\\/].*', r'\1', notebook_location))

# Project imports
from filter import ColorBlindnessFilter
from filter import DaltonizationFilter
from filter import DaltonizationLabEnchanceFilter
from filter import FourierEllipsoidFilter
from filter import FourierGaussianFilter
from filter import FourierUniformFilter
from filter import GaussianFilter
from filter import GaussianNoiseFilter
from filter import HistogramEqualizationFilter
from filter import SaltPepperNoiseFilter
from filter import SpeckleNoiseFilter
from filter import WaveletDenoiseFilter

# %% [markdown]
# A subset of the VGG16 validation images are used for this demonstration.  This subset contains only those images that were correctly classified by the VGG16 network.

# %%
images = np.load('data/vgg16_100_correct.npy', allow_pickle=True)
image_index = 11

# %% [markdown]
# ### Original Image

# %%
imshow(images[image_index][0]/255.)

# %% [markdown]
# ### Color Blindness Filter

# %%
filter = ColorBlindnessFilter()
imshow(filter.transform_image(['prot'], images[image_index][0])/255.)

# %% [markdown]
# ### Daltonization Filter

# %%
filter = DaltonizationFilter()
imshow(filter.transform_image(['prot'], images[image_index][0])/255.)

# %% [markdown]
# ### Daltonization and LAB Enhancement

# %%
filter = DaltonizationLabEnchanceFilter()
imshow(filter.transform_image(['prot'], images[image_index][0])/255.)

# %% [markdown]
# ### Fourier Ellipsoid

# %%
filter = FourierEllipsoidFilter()
imshow(filter.transform_image([5.22821402060977], images[image_index][0])/255.)

# %% [markdown]
# ### Fourier Gaussian

# %%
filter = FourierGaussianFilter()
imshow(filter.transform_image([1.8778320871128003], images[image_index][0])/255.)

# %% [markdown]
# ### Fourier Uniform

# %%
filter = FourierUniformFilter()
imshow(filter.transform_image([6.166303327191208], images[image_index][0])/255.)

# %% [markdown]
# ### Gaussian

# %%
filter = GaussianFilter()
imshow(filter.transform_image([2.74902560878921], images[image_index][0])/255.)

# %% [markdown]
# ### Gaussian Noise

# %%
filter = GaussianNoiseFilter(454)
imshow(filter.transform_image([-0.03604881411931221, 0.01], images[image_index][0])/255.)

# %% [markdown]
# ### Histogram Equalization

# %%
filter = HistogramEqualizationFilter()
imshow(filter.transform_image([256, False], images[image_index][0])/255.)
# Out:
# c:\repos\depaul\adversarial-filters\venv\lib\site-packages\skimage\exposure\exposure.py:181: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist, bin_centers = histogram(image, nbins)

# %% [markdown]
# ### Salt and Pepper Noise

# %%
filter = SaltPepperNoiseFilter(454)
imshow(filter.transform_image([0.02168783312793076, 0.99], images[image_index][0])/255.)

# %% [markdown]
# ### Speckle Noise

# %%
filter = SpeckleNoiseFilter(454)
imshow(filter.transform_image([-0.045288872530408475, 0.05], images[image_index][0])/255.)

# %% [markdown]
# ### Wavelet Denoise

# %%
filter = WaveletDenoiseFilter()
imshow(filter.transform_image([0.11260408762875708], images[image_index][0])/255.)
